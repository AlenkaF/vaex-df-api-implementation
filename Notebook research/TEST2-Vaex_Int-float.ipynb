# %%
# %run pandas_implementation

# %%
# %run vaex_implementation

# %%
import ipytest
ipytest.autoconfig()

# %%
# %%run_pytest[clean] -s
# # Testing roundtrip for int
# # data -> Vaex -> Vaex (from_dataframe_to_vaex) -> Pandas (from_dataframe) -> Vaex (from_dataframe_to_vaex)
#
# def test_roundtrip():
#
#     # Test data
#     x = np.array([1, 2, 0])
#     y = np.array([9, 10, 11])
#     df = vaex.from_arrays(x=x, y=y)
#
#     print("Data: Vaex and pointer")
#     b0 = df.x.to_numpy().__array_interface__['data'][0]
#
#     # Step 1
#     print("Step 1: Vaex (from_dataframe_to_vaex) and pointer")
#     df1 = from_dataframe_to_vaex(df)
#     b1 = df1.x.to_numpy().__array_interface__['data'][0]
#
#     print(df1)
#     print(b1)
#
#     # Step 2
#     print("Step 2: Pandas (from_dataframe) and pointer")
#     df2 = from_dataframe(df1)
#     b2 = df2.x.to_numpy().__array_interface__['data'][0]
#
#     print(df2)
#     print(b2)
#
#     # Step 3
#     print("Step 3: Vaex (from_dataframe_to_vaex) and pointer")
#     df3 = from_dataframe_to_vaex(df2)
#     b3 = df3.x.to_numpy().__array_interface__['data'][0]
#
#     print(df3)
#     print(b3)
#
#     print("\nData types")
#     print(f"df datatype for x: {df.x.dtype}  and y:  {df.y.dtype}")
#     print(f"df1 datatype for x: {df1.x.dtype}  and y:  {df1.y.dtype}")
#     print(f"df2 datatype for x: {df2.x.dtype}  and y:  {df2.y.dtype}")
#     print(f"df3 datatype for x: {df3.x.dtype}  and y:  {df3.y.dtype}")
#
#     assert b0 == b3
# Out:
# Data: Vaex and pointer
# Step 1: Vaex (from_dataframe_to_vaex) and pointer
#   #    x    y
#   0    1    9
#   1    2   10
#   2    0   11
# 2632042242912
# Step 2: Pandas (from_dataframe) and pointer
#    x   y
# 0  1   9
# 1  2  10
# 2  0  11
# 2632042242912
# Step 3: Vaex (from_dataframe_to_vaex) and pointer
#   #    x    y
#   0    1    9
#   1    2   10
#   2    0   11
# 2632042242912
#
# Data types
# df datatype for x: int32  and y:  int32
# df1 datatype for x: int32  and y:  int32
# df2 datatype for x: int32  and y:  int32
# df3 datatype for x: int32  and y:  int32
# .
# ================================================== warnings summary ===================================================
# ..\..\anaconda3\envs\df_protocol\lib\site-packages\pyreadline\py3k_compat.py:8
#   C:\Users\Alenka\anaconda3\envs\df_protocol\lib\site-packages\pyreadline\py3k_compat.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#     return isinstance(x, collections.Callable)
#
# -- Docs: https://docs.pytest.org/en/stable/warnings.html
# 1 passed, 1 warning in 0.02s

# %%
# %%run_pytest[clean] -s
# # Testing roundtrip for int & float mix
# # data -> Vaex -> Vaex (from_dataframe_to_vaex) -> Pandas (from_dataframe) -> Vaex (from_dataframe_to_vaex)
#
# def test_roundtrip():
#
#     # Test data
#     x = np.array([1, 2, 0])
#     y = np.array([9.2, 10.5, 11.8])
#     df = vaex.from_arrays(x=x, y=y)
#
#     print("Data: Vaex and pointer")
#     b0 = df.x.to_numpy().__array_interface__['data'][0]
#
#     # Step 1
#     print("Step 1: Vaex (from_dataframe_to_vaex) and pointer")
#     df1 = from_dataframe_to_vaex(df)
#     b1 = df1.x.to_numpy().__array_interface__['data'][0]
#
#     print(df1)
#     print(b1)
#
#     # Step 2
#     print("Step 2: Pandas (from_dataframe) and pointer")
#     df2 = from_dataframe(df1)
#     b2 = df2.x.to_numpy().__array_interface__['data'][0]
#
#     print(df2)
#     print(b2)
#
#     # Step 3
#     print("Step 3: Vaex (from_dataframe_to_vaex) and pointer")
#     df3 = from_dataframe_to_vaex(df2)
#     b3 = df3.x.to_numpy().__array_interface__['data'][0]
#
#     print(df3)
#     print(b3)
#
#     print("\nData types")
#     print(f"df datatype for x: {df.x.dtype}  and y:  {df.y.dtype}")
#     print(f"df1 datatype for x: {df1.x.dtype}  and y:  {df1.y.dtype}")
#     print(f"df2 datatype for x: {df2.x.dtype}  and y:  {df2.y.dtype}")
#     print(f"df3 datatype for x: {df3.x.dtype}  and y:  {df3.y.dtype}")
#
#     assert b0 == b3
# Out:
# Data: Vaex and pointer
# Step 1: Vaex (from_dataframe_to_vaex) and pointer
#   #    x     y
#   0    1   9.2
#   1    2  10.5
#   2    0  11.8
# 2632042243456
# Step 2: Pandas (from_dataframe) and pointer
#    x     y
# 0  1   9.2
# 1  2  10.5
# 2  0  11.8
# 2632042243456
# Step 3: Vaex (from_dataframe_to_vaex) and pointer
#   #    x     y
#   0    1   9.2
#   1    2  10.5
#   2    0  11.8
# 2632042243456
#
# Data types
# df datatype for x: int32  and y:  float64
# df1 datatype for x: int32  and y:  float64
# df2 datatype for x: int32  and y:  float64
# df3 datatype for x: int32  and y:  float64
# .
# 1 passed in 0.02s
