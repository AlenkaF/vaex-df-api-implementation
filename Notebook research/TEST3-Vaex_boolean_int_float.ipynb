# %%
# %run pandas_implementation

# %%
# %run vaex_implementation

# %%
import ipytest
ipytest.autoconfig()

# %%
# %%run_pytest[clean] -s
# # Testing roundtrip for int
# # data -> Vaex -> Vaex (from_dataframe_to_vaex) -> Pandas (from_dataframe) -> Vaex (from_dataframe_to_vaex)
#
# def test_roundtrip():
#
#     # Test data
#     x = np.array([True, True, False])
#     y = np.array([False, True, False])
#     df = vaex.from_arrays(x=x, y=y)
#
#     print("Data: Vaex and pointer")
#     b0 = df.x.to_numpy().__array_interface__['data'][0]
#
#     # Step 1
#     print("Step 1: Vaex (from_dataframe_to_vaex) and pointer")
#     df1 = from_dataframe_to_vaex(df)
#     b1 = df1.x.to_numpy().__array_interface__['data'][0]
#
#     print(df1)
#     print(b1)
#
#     # Step 2
#     print("Step 2: Pandas (from_dataframe) and pointer")
#     df2 = from_dataframe(df1)
#     b2 = df2.x.to_numpy().__array_interface__['data'][0]
#
#     print(df2)
#     print(b2)
#
#     # Step 3
#     print("Step 3: Vaex (from_dataframe_to_vaex) and pointer")
#     df3 = from_dataframe_to_vaex(df2)
#     b3 = df3.x.to_numpy().__array_interface__['data'][0]
#
#     print(df3)
#     print(b3)
#
#     print("\nData types")
#     print(f"df datatype for x: {df.x.dtype}  and y:  {df.y.dtype}")
#     print(f"df1 datatype for x: {df1.x.dtype}  and y:  {df1.y.dtype}")
#     print(f"df2 datatype for x: {df2.x.dtype}  and y:  {df2.y.dtype}")
#     print(f"df3 datatype for x: {df3.x.dtype}  and y:  {df3.y.dtype}")
#
#     assert b0 == b3
# Out:
# Data: Vaex and pointer
# Step 1: Vaex (from_dataframe_to_vaex) and pointer
#   #  x      y
#   0  True   False
#   1  True   True
#   2  False  False
# 2552211164368
# Step 2: Pandas (from_dataframe) and pointer
#        x      y
# 0   True  False
# 1   True   True
# 2  False  False
# 2552211164368
# Step 3: Vaex (from_dataframe_to_vaex) and pointer
#   #  x      y
#   0  True   False
#   1  True   True
#   2  False  False
# 2552211164368
#
# Data types
# df datatype for x bool  and y  bool
# df1 datatype for x bool  and y  bool
# df2 datatype for x bool  and y  bool
# df3 datatype for x bool  and y  bool
# .
# 1 passed in 0.01s

# %%
# %%run_pytest[clean] -s
# # Testing roundtrip for int
# # data -> Vaex -> Vaex (from_dataframe_to_vaex) -> Pandas (from_dataframe) -> Vaex (from_dataframe_to_vaex)
#
# def test_roundtrip():
#
#     # Test data
#     x = np.array([True, True, False])
#     y = np.array([1, 2, 0])
#     z = np.array([9.2, 10.5, 11.8])
#     df = vaex.from_arrays(x=x, y=y, z=z)
#
#     print("Data: Vaex and pointer")
#     b0 = df.x.to_numpy().__array_interface__['data'][0]
#
#     # Step 1
#     print("Step 1: Vaex (from_dataframe_to_vaex) and pointer")
#     df1 = from_dataframe_to_vaex(df)
#     b1 = df1.x.to_numpy().__array_interface__['data'][0]
#
#     print(df1)
#     print(b1)
#
#     # Step 2
#     print("Step 2: Pandas (from_dataframe) and pointer")
#     df2 = from_dataframe(df1)
#     b2 = df2.x.to_numpy().__array_interface__['data'][0]
#
#     print(df2)
#     print(b2)
#
#     # Step 3
#     print("Step 3: Vaex (from_dataframe_to_vaex) and pointer")
#     df3 = from_dataframe_to_vaex(df2)
#     b3 = df3.x.to_numpy().__array_interface__['data'][0]
#
#     print(df3)
#     print(b3)
#
#     print("\nData types")
#     print(f"df datatype for x: {df.x.dtype}  and y:  {df.y.dtype} and z:  {df.z.dtype}")
#     print(f"df1 datatype for x: {df1.x.dtype}  and y:  {df1.y.dtype} and z:  {df1.z.dtype}")
#     print(f"df2 datatype for x: {df2.x.dtype}  and y:  {df2.y.dtype} and z:  {df2.z.dtype}")
#     print(f"df3 datatype for x: {df3.x.dtype}  and y:  {df3.y.dtype} and z:  {df3.z.dtype}")
#
#     assert b0 == b3
# Out:
# Data: Vaex and pointer
# Step 1: Vaex (from_dataframe_to_vaex) and pointer
#   #  x        y     z
#   0  True     1   9.2
#   1  True     2  10.5
#   2  False    0  11.8
# 2552211164896
# Step 2: Pandas (from_dataframe) and pointer
#        x  y     z
# 0   True  1   9.2
# 1   True  2  10.5
# 2  False  0  11.8
# 2552211164896
# Step 3: Vaex (from_dataframe_to_vaex) and pointer
#   #  x        y     z
#   0  True     1   9.2
#   1  True     2  10.5
#   2  False    0  11.8
# 2552211164896
#
# Data types
# df datatype for x: bool  and y:  int32 and z:  float64
# df1 datatype for x: bool  and y:  int32 and z:  float64
# df2 datatype for x: bool  and y:  int32 and z:  float64
# df3 datatype for x: bool  and y:  int32 and z:  float64
# .
# 1 passed in 0.01s
